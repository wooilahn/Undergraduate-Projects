# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

import nn.layers as layers
import nn.optim as optim
import nn.net as net
from nn.solver import Solver
from utils import *
from dataset import get_CIFAR10_data

# %% [markdown]
# # Fully-conneceted (Linear) layer
# `nn/layers.py` 파일 내부에 있는 `Linear` 클래스의 `forward`와 `backward` 메소드를 주석에 명시된 요구 조건에 따라 작성하고, 아래 코드를 실행시켜 구현한 코드를 테스트한다.<br>
# **NOTE**: 모든 테스트 결과는 *1e-06* 이하의 오차만 허용된다.

# %%
# Test the Linear.forward()
num_input, in_dims, out_dims = 3, 5, 3

linear = layers.Linear(in_dims, out_dims, init_mode="linear")
x = np.linspace(-0.1, 0.5, num=num_input*in_dims).reshape(num_input, in_dims)

out = linear.forward(x)
correct_out = np.array([[ 0.01938776,  0.01836735,  0.01734694],
                        [ 0.00408163,  0.01836735,  0.03265306],
                        [-0.01122449,  0.01836735,  0.04795918],])
print("Testing linear - forward function:")
print("error:", rel_error(out, correct_out))
# Out:
# Testing linear - forward function:
# error: 3.2500010554504164e-07

# %% [markdown]
# # Activation functions
# `nn/layers.py` 파일 내부에 있는 `ReLU`, `Sigmoid`, `Tanh` 클래스의 `forward` 및 `backward` 메소드를 주석에 명시된 요구 조건에 따라 작성하고, 아래 코드를 실행시켜 구현한 코드를 테스트한다.<br>
# **NOTE**: 모든 테스트 결과는 *1e-06* 이하의 오차만 허용된다.

# %%
# Test the ReLU.forward()
relu = layers.ReLU()
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out = relu.forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

print("Testing ReLU - forward function:")
print("error:", rel_error(out, correct_out))

# Test the ReLU.backward()
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu.forward(x), x, dout)

relu.forward(x)
dx = relu.backward(dout)

print("\nTesting ReLU - backward function:")
print("dx error:", rel_error(dx, dx_num))
# Out:
# Testing ReLU - forward function:
# error: 4.999999798022158e-08
#
# Testing ReLU - backward function:
# dx error: 3.2756238620250274e-12

# %%
# Test the Sigmoid.forward()
sigmoid = layers.Sigmoid()
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out = sigmoid.forward(x)
correct_out = np.array([[0.37754067, 0.39913012, 0.42111892, 0.44342513],
                        [0.46596182, 0.48863832, 0.51136168, 0.53403818],
                        [0.55657487, 0.57888108, 0.60086988, 0.62245933],])

print("Testing Sigmoid - forward function:")
print("error:", rel_error(out, correct_out))

# Test the Sigmoid.backward()
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: sigmoid.forward(x), x, dout)

sigmoid.forward(x)
dx = sigmoid.backward(dout)

print("\nTesting Sigmoid - backward function:")
print("dx error:", rel_error(dx, dx_num))
# Out:
# Testing Sigmoid - forward function:
# error: 5.157221295671855e-09
#
# Testing Sigmoid - backward function:
# dx error: 3.622416264856414e-11

# %%
# Test the Tanh.forward()
tanh = layers.Tanh()
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out = tanh.forward(x)
correct_out = np.array([[-0.46211716, -0.38770051, -0.30786199, -0.22343882],
                        [-0.13552465, -0.04542327,  0.04542327,  0.13552465],
                        [ 0.22343882,  0.30786199,  0.38770051,  0.46211716],])

print("Testing Tanh - forward function:")
print("error:", rel_error(out, correct_out))

# Test the Tanh.backward()
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: tanh.forward(x), x, dout)

tanh.forward(x)
dx = tanh.backward(dout)

print("\nTesting Tanh - backward function:")
print("dx error:", rel_error(dx, dx_num))
# Out:
# Testing Tanh - forward function:
# error: 3.8292287781296644e-08
#
# Testing Tanh - backward function:
# dx error: 9.449233360334576e-11

# %% [markdown]
# # Loss layer: Softmax-CrossEntropy
# `nn/layers.py` 파일 내부에 있는 `SoftmaxCELoss` 클래스의 `forward` 메소드를 주석에 명시된 요구 조건에 따라 작성하고, 아래 코드를 실행시켜 구현한 코드를 테스트한다.<br>
# 주의: 구현의 편의성을 위해 별도의 `backward` 메소드 없이 `forward` 함수 내부에서 loss와 gradient를 계산하도록 되어있다.<br>
# **NOTE**: 모든 테스트 결과는 *1e-06* 이하의 오차만 허용된다.

# %%
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)

ce = layers.SoftmaxCELoss()

dx_num = eval_numerical_gradient(lambda x: ce.forward(x, y)[0], x, verbose=False)
loss, dx = ce.forward(x, y)

print("Testing softmax loss:")
print("loss:", loss, " (must be around 2.3)")
print("dx error:", rel_error(dx, dx_num))
# Out:
# Testing softmax loss:
# loss: 2.302827700104812  (must be around 2.3)
# dx error: 8.309794259683745e-09

# %% [markdown]
# # Two-layer Network
# 이전까지 구현한 모듈들을 조합하여 레이어 2개짜리 네트워크를 작성한다. `nn/net.py` 파일에 있는 `TwoLayerNet` 클래스의 생성자 및 `loss` 함수를 구현한 뒤, 아래 코드를 실행하여 테스트 한다.<br>
# **NOTE**: 모든 테스트 결과는 *1e-06* 이하의 오차만 허용된다.

# %%
N, D, H, C = 3, 5, 50, 7
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
y = np.asarray([0, 5, 1])

mynet = net.TwoLayerNet(D, H, C)
mynet.modules["linear1"].params["w"] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
mynet.modules["linear1"].params["b"] = np.linspace(-0.1, 0.9, num=H)
mynet.modules["linear2"].params["w"] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
mynet.modules["linear2"].params["b"] = np.linspace(-0.9, 0.1, num=C)

scores = mynet.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
correct_loss = 3.4702243556

print("Testing TwoLayerNet:")
print("score error:", np.abs(scores - correct_scores).sum())

loss = mynet.loss(X, y)
print("loss error:", np.abs(loss - correct_loss))

loss = mynet.loss(X, y)
f = lambda _: mynet.loss(X, y)
grad_w2 = eval_numerical_gradient(f, mynet.modules["linear2"].params["w"], verbose=False)
grad_b2 = eval_numerical_gradient(f, mynet.modules["linear2"].params["b"], verbose=False)
grad_w1 = eval_numerical_gradient(f, mynet.modules["linear1"].params["w"], verbose=False)
grad_b1 = eval_numerical_gradient(f, mynet.modules["linear1"].params["b"], verbose=False)

print()
print("grad_w2 error:", rel_error(grad_w2, mynet.modules["linear2"].grads["w"]))
print("grad_b2 error:", rel_error(grad_b2, mynet.modules["linear2"].grads["b"]))
print("grad_w1 error:", rel_error(grad_w1, mynet.modules["linear1"].grads["w"]))
print("grad_b1 error:", rel_error(grad_b1, mynet.modules["linear1"].grads["b"]))
# Out:
# Testing TwoLayerNet:
# score error: 5.1158512093252284e-08
# loss error: 4.6100900874535e-12
#
# grad_w2 error: 9.866878677927891e-07
# grad_b2 error: 3.07701795131934e-08
# grad_w1 error: 1.912271846914164e-08
# grad_b1 error: 1.1584813448516334e-08

# %%
# Test the Linear.backward()
num_input, in_dims, out_dims = 10, 6, 5

linear = layers.Linear(in_dims, out_dims, init_mode="normal")
x = np.linspace(-0.1, 0.5, num=num_input*in_dims).reshape(num_input, in_dims)
dout = np.random.randn(num_input, out_dims)

dx_num = eval_numerical_gradient_array(lambda x: linear.forward(x), x, dout)
dw_num = eval_numerical_gradient_array(lambda w: linear.forward(x), linear.params["w"], dout)
db_num = eval_numerical_gradient_array(lambda b: linear.forward(x), linear.params["b"], dout)

out = linear.forward(x)
linear.backward(dout)

dx, dw, db = linear.grads["x"], linear.grads["w"], linear.grads["b"]

print("Testing linear - backward function:")
print("dx error:", rel_error(dx, dx_num))
print("dw error:", rel_error(dw, dw_num))
print("db error:", rel_error(db, db_num))
# Out:
# Testing linear - backward function:
# dx error: 2.83312912943617e-10
# dw error: 2.934764445444176e-14
# db error: 4.581730043447813e-13

# %% [markdown]
# # Solver and train the network
# 위에서 작성한 2-레이어 네트워크를 학습한다. 네트워크의 학습을 CIFAR-10 데이터를 사용하여 (`dataset.py` 참조), `nn.Solver` 파일의 `Solver` 클래스에 의해 학습이 진행된다. 대부분의 코드가 미리 작성되었기 때문에  `nn.Solver` 파일의 클래스의 API를 참조하여 아래 **TODO** 부분을 작성한다. **TODO** 부분은 네트워크 하이퍼파라미터 세팅에 관한 코드가 들어가야 하며, validation set에 대해 **50%** 이상의 성능을 보여야 한다.

# %%
# Load the (preprocessed) CIFAR10 data.
data = get_CIFAR10_data()
for k, v in data.items():
    print(k, v.shape)
# Out:
# X_train (49000, 3, 32, 32)
# y_train (49000,)
# X_val (1000, 3, 32, 32)
# y_val (1000,)
# X_test (1000, 3, 32, 32)
# y_test (1000,)

# %%
model = net.TwoLayerNet(init_mode="normal", init_scale=0.001)
solver = None

######################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves   #
# at least **50%** accuracy on the validation set.                   #
######################################################################
solver = Solver(model, data, batch_size=10, num_epochs=50)
######################################################################
#                          END OF YOUR CODE                          #
######################################################################
solver.train()

# plot results
plt.subplot(2, 1, 1)
plt.title("Training loss")
plt.plot(solver.loss_history, "-")
plt.xlabel("Steps")

plt.subplot(2, 1, 2)
plt.title("Accuracy")
plt.plot(solver.train_acc_history, "-o", label="train")
plt.plot(solver.val_acc_history, "-o", label="val")
plt.plot([0.5] * len(solver.val_acc_history), "k--")
plt.xlabel("Epoch")
plt.legend(loc="lower right")
plt.gcf().set_size_inches(15, 12)
plt.show()
# Out:
# Epoch 0/50
#   Loss: 2.303
#   Train accuracy: 0.083
#   Val accuracy: 0.105
# Epoch 1/50
#   Loss: 2.298
#   Train accuracy: 0.155
#   Val accuracy: 0.149
# Epoch 2/50
#   Loss: 2.136
#   Train accuracy: 0.201
#   Val accuracy: 0.202
# Epoch 3/50
#   Loss: 2.225
#   Train accuracy: 0.233
#   Val accuracy: 0.260
# Epoch 4/50
#   Loss: 2.058
#   Train accuracy: 0.278
#   Val accuracy: 0.283
# Epoch 5/50
#   Loss: 1.514
#   Train accuracy: 0.291
#   Val accuracy: 0.287
# Epoch 6/50
#   Loss: 1.782
#   Train accuracy: 0.325
#   Val accuracy: 0.333
# Epoch 7/50
#   Loss: 1.970
#   Train accuracy: 0.321
#   Val accuracy: 0.335
# Epoch 8/50
#   Loss: 2.040
#   Train accuracy: 0.336
#   Val accuracy: 0.365
# Epoch 9/50
#   Loss: 2.000
#   Train accuracy: 0.348
#   Val accuracy: 0.371
# Epoch 10/50
#   Loss: 1.633
#   Train accuracy: 0.366
#   Val accuracy: 0.381
# Epoch 11/50
#   Loss: 1.574
#   Train accuracy: 0.384
#   Val accuracy: 0.387
# Epoch 12/50
#   Loss: 1.728
#   Train accuracy: 0.379
#   Val accuracy: 0.403
# Epoch 13/50
#   Loss: 1.716
#   Train accuracy: 0.406
#   Val accuracy: 0.415
# Epoch 14/50
#   Loss: 1.450
#   Train accuracy: 0.424
#   Val accuracy: 0.430
# Epoch 15/50
#   Loss: 2.009
#   Train accuracy: 0.446
#   Val accuracy: 0.439
# Epoch 16/50
#   Loss: 1.696
#   Train accuracy: 0.417
#   Val accuracy: 0.433
# Epoch 17/50
#   Loss: 1.711
#   Train accuracy: 0.452
#   Val accuracy: 0.451
# Epoch 18/50
#   Loss: 1.886
#   Train accuracy: 0.434
#   Val accuracy: 0.451
# Epoch 19/50
#   Loss: 1.112
#   Train accuracy: 0.453
#   Val accuracy: 0.448
# Epoch 20/50
#   Loss: 1.861
#   Train accuracy: 0.465
#   Val accuracy: 0.462
# Epoch 21/50
#   Loss: 1.522
#   Train accuracy: 0.469
#   Val accuracy: 0.463
# Epoch 22/50
#   Loss: 1.590
#   Train accuracy: 0.453
#   Val accuracy: 0.465
# Epoch 23/50
#   Loss: 1.528
#   Train accuracy: 0.493
#   Val accuracy: 0.466
# Epoch 24/50
#   Loss: 2.217
#   Train accuracy: 0.497
#   Val accuracy: 0.460
# Epoch 25/50
#   Loss: 1.205
#   Train accuracy: 0.494
#   Val accuracy: 0.462
# Epoch 26/50
#   Loss: 1.420
#   Train accuracy: 0.482
#   Val accuracy: 0.471
# Epoch 27/50
#   Loss: 1.472
#   Train accuracy: 0.498
#   Val accuracy: 0.474
# Epoch 28/50
#   Loss: 1.909
#   Train accuracy: 0.474
#   Val accuracy: 0.472
# Epoch 29/50
#   Loss: 1.396
#   Train accuracy: 0.500
#   Val accuracy: 0.480
# Epoch 30/50
#   Loss: 1.508
#   Train accuracy: 0.517
#   Val accuracy: 0.476
# Epoch 31/50
#   Loss: 1.977
#   Train accuracy: 0.489
#   Val accuracy: 0.470
# Epoch 32/50
#   Loss: 1.472
#   Train accuracy: 0.509
#   Val accuracy: 0.479
# Epoch 33/50
#   Loss: 1.076
#   Train accuracy: 0.512
#   Val accuracy: 0.477
# Epoch 34/50
#   Loss: 1.226
#   Train accuracy: 0.541
#   Val accuracy: 0.484
# Epoch 35/50
#   Loss: 1.055
#   Train accuracy: 0.501
#   Val accuracy: 0.483
# Epoch 36/50
#   Loss: 1.636
#   Train accuracy: 0.529
#   Val accuracy: 0.487
# Epoch 37/50
#   Loss: 1.384
#   Train accuracy: 0.503
#   Val accuracy: 0.486
# Epoch 38/50
#   Loss: 1.085
#   Train accuracy: 0.527
#   Val accuracy: 0.495
# Epoch 39/50
#   Loss: 1.177
#   Train accuracy: 0.516
#   Val accuracy: 0.500
# Epoch 40/50
#   Loss: 1.547
#   Train accuracy: 0.516
#   Val accuracy: 0.507
# Epoch 41/50
#   Loss: 0.917
#   Train accuracy: 0.549
#   Val accuracy: 0.506
# Epoch 42/50
#   Loss: 1.238
#   Train accuracy: 0.522
#   Val accuracy: 0.503
# Epoch 43/50
#   Loss: 1.719
#   Train accuracy: 0.538
#   Val accuracy: 0.500
# Epoch 44/50
#   Loss: 1.585
#   Train accuracy: 0.535
#   Val accuracy: 0.501
# Epoch 45/50
#   Loss: 1.221
#   Train accuracy: 0.544
#   Val accuracy: 0.505
# Epoch 46/50
#   Loss: 1.102
#   Train accuracy: 0.545
#   Val accuracy: 0.506
# Epoch 47/50
#   Loss: 1.046
#   Train accuracy: 0.554
#   Val accuracy: 0.507
# Epoch 48/50
#   Loss: 1.435
#   Train accuracy: 0.555
#   Val accuracy: 0.516
# Epoch 49/50
#   Loss: 1.190
#   Train accuracy: 0.583
#   Val accuracy: 0.507
# Epoch 50/50
#   Loss: 1.544
#   Train accuracy: 0.545
#   Val accuracy: 0.514

# %% [markdown]
# # Multi-layer network
# 이제 `nn/net.py`의 `FCNet` 클래스의 빈칸을 작성하여, 레이어가 여러 개인 네트워크를 디자인한다. 이 때, 임의의 레이어 개수를 입력으로 받도록 for loop를 사용해서 네트워크를 구성하고 forward/backward 연산을 수행해야만 한다. 그 후, 네트워크를 테스트하고 (numerical 이슈에 의해 상대 오차가 비교적 클 가능성이 있으므로, 테스트 코드를 반복 실행하여 바뀌는 오차를 확인한다.) `TwoLayerNet` 과 동일한 하이퍼파라미터를 사용하여 네트워크를 학습한다.<br>
# **주의**: 성능이 낮게 나오는 것이 정상이므로 여기서 별도의 하이퍼파라미터 튜닝을 진행하지 않는다.

# %%
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

model = net.FCNet(
    input_dim=D, num_classes=C,
    hidden_dims=[H1, H2],
    init_scale=5e-2, init_mode="normal"
)

loss = model.loss(X, y)
print("Initial loss:", loss)

for module_name in model.modules.keys():
    if not model.modules[module_name].params:
        continue
        
    w = model.modules[module_name].params["w"]
    b = model.modules[module_name].params["b"]
    dw = model.modules[module_name].grads["w"]
    db = model.modules[module_name].grads["b"]
    
    f = lambda _: model.loss(X, y)
    grad_w = eval_numerical_gradient(f, w, verbose=False, h=1e-5)
    grad_b = eval_numerical_gradient(f, b, verbose=False, h=1e-5)

    print("{}_w error: {:e}".format(module_name, rel_error(dw, grad_w)))
    print("{}_b error: {:e}".format(module_name, rel_error(db, grad_b)))
# Out:
# Initial loss: 2.301004757621881
# linear1_w error: 9.540930e-07
# linear1_b error: 7.282743e-09
# linear2_w error: 1.226780e-04
# linear2_b error: 5.671340e-06
# linear3_w error: 9.314953e-04
# linear3_b error: 2.197270e-07

# %%
model = net.FCNet(
    hidden_dims=[100, 100],
    init_scale=0.001, init_mode="normal"
)
solver = None

######################################################################
# TODO: Use the same solver settings that used when training         #
# TwoLayerNet model                                                  #
######################################################################
solver = Solver(model, data, batch_size=10, num_epochs=50)
######################################################################
#                          END OF YOUR CODE                          #
######################################################################
solver.train()

# plot results
plt.subplot(2, 1, 1)
plt.title("Training loss")
plt.plot(solver.loss_history, "-")
plt.xlabel("Steps")

plt.subplot(2, 1, 2)
plt.title("Accuracy")
plt.plot(solver.train_acc_history, "-o", label="train")
plt.plot(solver.val_acc_history, "-o", label="val")
plt.plot([0.5] * len(solver.val_acc_history), "k--")
plt.xlabel("Epoch")
plt.legend(loc="lower right")
plt.gcf().set_size_inches(15, 12)
plt.show()
# Out:
# Epoch 0/50
#   Loss: 2.303
#   Train accuracy: 0.110
#   Val accuracy: 0.105
# Epoch 1/50
#   Loss: 2.303
#   Train accuracy: 0.107
#   Val accuracy: 0.105
# Epoch 2/50
#   Loss: 2.305
#   Train accuracy: 0.114
#   Val accuracy: 0.079
# Epoch 3/50
#   Loss: 2.303
#   Train accuracy: 0.097
#   Val accuracy: 0.113
# Epoch 4/50
#   Loss: 2.306
#   Train accuracy: 0.108
#   Val accuracy: 0.113
# Epoch 5/50
#   Loss: 2.302
#   Train accuracy: 0.082
#   Val accuracy: 0.113
# Epoch 6/50
#   Loss: 2.302
#   Train accuracy: 0.111
#   Val accuracy: 0.079
# Epoch 7/50
#   Loss: 2.301
#   Train accuracy: 0.104
#   Val accuracy: 0.078
# Epoch 8/50
#   Loss: 2.303
#   Train accuracy: 0.096
#   Val accuracy: 0.105
# Epoch 9/50
#   Loss: 2.299
#   Train accuracy: 0.105
#   Val accuracy: 0.105
# Epoch 10/50
#   Loss: 2.306
#   Train accuracy: 0.095
#   Val accuracy: 0.105
# Epoch 11/50
#   Loss: 2.306
#   Train accuracy: 0.100
#   Val accuracy: 0.079
# Epoch 12/50
#   Loss: 2.302
#   Train accuracy: 0.111
#   Val accuracy: 0.079
# Epoch 13/50
#   Loss: 2.302
#   Train accuracy: 0.094
#   Val accuracy: 0.079
# Epoch 14/50
#   Loss: 2.302
#   Train accuracy: 0.100
#   Val accuracy: 0.079
# Epoch 15/50
#   Loss: 2.302
#   Train accuracy: 0.101
#   Val accuracy: 0.079
# Epoch 16/50
#   Loss: 2.303
#   Train accuracy: 0.098
#   Val accuracy: 0.087
# Epoch 17/50
#   Loss: 2.304
#   Train accuracy: 0.107
#   Val accuracy: 0.087
# Epoch 18/50
#   Loss: 2.302
#   Train accuracy: 0.097
#   Val accuracy: 0.087
# Epoch 19/50
#   Loss: 2.304
#   Train accuracy: 0.099
#   Val accuracy: 0.079
# Epoch 20/50
#   Loss: 2.303
#   Train accuracy: 0.115
#   Val accuracy: 0.113
# Epoch 21/50
#   Loss: 2.301
#   Train accuracy: 0.118
#   Val accuracy: 0.113
# Epoch 22/50
#   Loss: 2.302
#   Train accuracy: 0.113
#   Val accuracy: 0.102
# Epoch 23/50
#   Loss: 2.304
#   Train accuracy: 0.108
#   Val accuracy: 0.102
# Epoch 24/50
#   Loss: 2.303
#   Train accuracy: 0.090
#   Val accuracy: 0.107
# Epoch 25/50
#   Loss: 2.300
#   Train accuracy: 0.101
#   Val accuracy: 0.079
# Epoch 26/50
#   Loss: 2.308
#   Train accuracy: 0.109
#   Val accuracy: 0.079
# Epoch 27/50
#   Loss: 2.302
#   Train accuracy: 0.099
#   Val accuracy: 0.079
# Epoch 28/50
#   Loss: 2.305
#   Train accuracy: 0.099
#   Val accuracy: 0.078
# Epoch 29/50
#   Loss: 2.304
#   Train accuracy: 0.094
#   Val accuracy: 0.078
# Epoch 30/50
#   Loss: 2.302
#   Train accuracy: 0.092
#   Val accuracy: 0.079
# Epoch 31/50
#   Loss: 2.307
#   Train accuracy: 0.100
#   Val accuracy: 0.079
# Epoch 32/50
#   Loss: 2.303
#   Train accuracy: 0.109
#   Val accuracy: 0.078
# Epoch 33/50
#   Loss: 2.306
#   Train accuracy: 0.104
#   Val accuracy: 0.078
# Epoch 34/50
#   Loss: 2.301
#   Train accuracy: 0.088
#   Val accuracy: 0.078
# Epoch 35/50
#   Loss: 2.298
#   Train accuracy: 0.101
#   Val accuracy: 0.079
# Epoch 36/50
#   Loss: 2.297
#   Train accuracy: 0.109
#   Val accuracy: 0.112
# Epoch 37/50
#   Loss: 2.304
#   Train accuracy: 0.114
#   Val accuracy: 0.102
# Epoch 38/50
#   Loss: 2.300
#   Train accuracy: 0.110
#   Val accuracy: 0.102
# Epoch 39/50
#   Loss: 2.305
#   Train accuracy: 0.107
#   Val accuracy: 0.102
# Epoch 40/50
#   Loss: 2.302
#   Train accuracy: 0.088
#   Val accuracy: 0.102
# Epoch 41/50
#   Loss: 2.301
#   Train accuracy: 0.098
#   Val accuracy: 0.078
# Epoch 42/50
#   Loss: 2.305
#   Train accuracy: 0.089
#   Val accuracy: 0.107
# Epoch 43/50
#   Loss: 2.300
#   Train accuracy: 0.097
#   Val accuracy: 0.107
# Epoch 44/50
#   Loss: 2.303
#   Train accuracy: 0.097
#   Val accuracy: 0.107
# Epoch 45/50
#   Loss: 2.300
#   Train accuracy: 0.109
#   Val accuracy: 0.107
# Epoch 46/50
#   Loss: 2.302
#   Train accuracy: 0.109
#   Val accuracy: 0.078
# Epoch 47/50
#   Loss: 2.302
#   Train accuracy: 0.095
#   Val accuracy: 0.119
# Epoch 48/50
#   Loss: 2.305
#   Train accuracy: 0.103
#   Val accuracy: 0.078
# Epoch 49/50
#   Loss: 2.306
#   Train accuracy: 0.106
#   Val accuracy: 0.107
# Epoch 50/50
#   Loss: 2.303
#   Train accuracy: 0.102
#   Val accuracy: 0.087

# %% [markdown]
# # Better initialization
# 지금까지는 네트워크의 weight를 std=0.001인 가우시안 분포를 사용하여 초기화 하였다 (`nn/init.py`의 `_normal_init` 함수 참조). 하지만 이 초기화 방법은 위와 같이 레이어를 깊게 쌓은 경우 성능을 올리기가 매우 어렵다는 단점이 있다. 이를 해결하고자 Xavier [1], He [2] 초기화 방법이 제안되었다.<br>
# 아래 코드를 실행시켜보고 문제에 대해 답을 서술해보자.
#
# [1] Glorot, Xavier, and Yoshua Bengio. "Understanding the difficulty of training deep feedforward neural networks." ICAIS 2010.<br>
# [2] He, Kaiming, et al. "Delving deep into rectifiers: Surpassing human-level performance on imagenet classification." ICCV 2015.
#
# ## Question:
# 1. std=0.001인 가우시안 분포로 네트워크의 weight를 초기화한 모델의 학습이 되지 않는 이유가 무엇일까?
# 2. He 초기화 방법은 가우시안 분포 초기화 어떤 장점을 가지고 있을까?
#
# ## Answer:
#
# 1. 가우시안 분포는 정규분포를 의미한다. 이 때, 표준편차가 그렇게 크지 않게되면, backward를 위한 propagation의 값이 사라져 버리는 Gradient Vanishing 현상이 발생하게 되게 된다. 따라서 std=0.001인 가우시안 분포로 네트워크의 weight를 초기화한 모델은 학습이 제대로 되지 않는다.
#
# 2. Xavier 초기화 방법은 표준 정규 분포를 입력 개수의 표준 편차로 나누면 되고, He 초기화는 표준 정규 분포를 인풋 개수의 절반의 제곱근으로 나누면 된다. 보통 Sigmoid 나 Tanh 를 사용할 경우에는 Xavier 초기화를 사용하고,  ReLU 를 사용할 경우에는 He 초기화를 사용하는 경우가 많다. 과제에서 작성한 코드들은 ReLU Activation을 사용하였으므로 He 초기화를 가우시안 분포 초기화 대신에 사용하게 되면, 파라미터들의 초기값을 조절하여 더 좋은 성능을 얻을 수 있다.

# %%
model = net.FCNet(
    hidden_dims=[100, 100],
    init_mode="he" # or use xavier
)
solver = None

######################################################################
# TODO: Use the same solver settings that used when training         #
# TwoLayerNet model                                                  #
######################################################################
solver = Solver(model, data, batch_size=10, num_epochs=50)
######################################################################
#                          END OF YOUR CODE                          #
######################################################################
solver.train()

# plot results
plt.subplot(2, 1, 1)
plt.title("Training loss")
plt.plot(solver.loss_history, "-")
plt.xlabel("Steps")

plt.subplot(2, 1, 2)
plt.title("Accuracy")
plt.plot(solver.train_acc_history, "-o", label="train")
plt.plot(solver.val_acc_history, "-o", label="val")
plt.plot([0.5] * len(solver.val_acc_history), "k--")
plt.xlabel("Epoch")
plt.legend(loc="lower right")
plt.gcf().set_size_inches(15, 12)
plt.show()
# Out:
# Epoch 0/50
#   Loss: 2.358
#   Train accuracy: 0.094
#   Val accuracy: 0.076
# Epoch 1/50
#   Loss: 1.932
#   Train accuracy: 0.348
#   Val accuracy: 0.361
# Epoch 2/50
#   Loss: 1.525
#   Train accuracy: 0.409
#   Val accuracy: 0.410
# Epoch 3/50
#   Loss: 1.679
#   Train accuracy: 0.445
#   Val accuracy: 0.427
# Epoch 4/50
#   Loss: 2.393
#   Train accuracy: 0.449
#   Val accuracy: 0.441
# Epoch 5/50
#   Loss: 1.034
#   Train accuracy: 0.481
#   Val accuracy: 0.453
# Epoch 6/50
#   Loss: 1.744
#   Train accuracy: 0.497
#   Val accuracy: 0.462
# Epoch 7/50
#   Loss: 1.300
#   Train accuracy: 0.466
#   Val accuracy: 0.496
# Epoch 8/50
#   Loss: 1.858
#   Train accuracy: 0.470
#   Val accuracy: 0.485
# Epoch 9/50
#   Loss: 1.724
#   Train accuracy: 0.506
#   Val accuracy: 0.485
# Epoch 10/50
#   Loss: 0.836
#   Train accuracy: 0.497
#   Val accuracy: 0.494
# Epoch 11/50
#   Loss: 1.332
#   Train accuracy: 0.525
#   Val accuracy: 0.500
# Epoch 12/50
#   Loss: 1.477
#   Train accuracy: 0.540
#   Val accuracy: 0.502
# Epoch 13/50
#   Loss: 0.859
#   Train accuracy: 0.529
#   Val accuracy: 0.497
# Epoch 14/50
#   Loss: 1.249
#   Train accuracy: 0.551
#   Val accuracy: 0.502
# Epoch 15/50
#   Loss: 1.636
#   Train accuracy: 0.533
#   Val accuracy: 0.495
# Epoch 16/50
#   Loss: 0.831
#   Train accuracy: 0.540
#   Val accuracy: 0.506
# Epoch 17/50
#   Loss: 0.968
#   Train accuracy: 0.567
#   Val accuracy: 0.499
# Epoch 18/50
#   Loss: 1.001
#   Train accuracy: 0.541
#   Val accuracy: 0.508
# Epoch 19/50
#   Loss: 0.903
#   Train accuracy: 0.573
#   Val accuracy: 0.519
# Epoch 20/50
#   Loss: 0.768
#   Train accuracy: 0.582
#   Val accuracy: 0.518
# Epoch 21/50
#   Loss: 1.146
#   Train accuracy: 0.591
#   Val accuracy: 0.519
# Epoch 22/50
#   Loss: 1.247
#   Train accuracy: 0.557
#   Val accuracy: 0.521
# Epoch 23/50
#   Loss: 1.223
#   Train accuracy: 0.585
#   Val accuracy: 0.534
# Epoch 24/50
#   Loss: 0.603
#   Train accuracy: 0.607
#   Val accuracy: 0.528
# Epoch 25/50
#   Loss: 1.394
#   Train accuracy: 0.603
#   Val accuracy: 0.521
# Epoch 26/50
#   Loss: 0.972
#   Train accuracy: 0.563
#   Val accuracy: 0.529
# Epoch 27/50
#   Loss: 1.646
#   Train accuracy: 0.582
#   Val accuracy: 0.526
# Epoch 28/50
#   Loss: 0.741
#   Train accuracy: 0.583
#   Val accuracy: 0.525
# Epoch 29/50
#   Loss: 1.349
#   Train accuracy: 0.620
#   Val accuracy: 0.521
# Epoch 30/50
#   Loss: 1.178
#   Train accuracy: 0.601
#   Val accuracy: 0.527
# Epoch 31/50
#   Loss: 0.819
#   Train accuracy: 0.621
#   Val accuracy: 0.538
# Epoch 32/50
#   Loss: 0.875
#   Train accuracy: 0.579
#   Val accuracy: 0.533
# Epoch 33/50
#   Loss: 0.539
#   Train accuracy: 0.620
#   Val accuracy: 0.537
# Epoch 34/50
#   Loss: 1.203
#   Train accuracy: 0.604
#   Val accuracy: 0.535
# Epoch 35/50
#   Loss: 1.076
#   Train accuracy: 0.617
#   Val accuracy: 0.553
# Epoch 36/50
#   Loss: 0.538
#   Train accuracy: 0.632
#   Val accuracy: 0.539
# Epoch 37/50
#   Loss: 1.070
#   Train accuracy: 0.616
#   Val accuracy: 0.539
# Epoch 38/50
#   Loss: 1.340
#   Train accuracy: 0.625
#   Val accuracy: 0.547
# Epoch 39/50
#   Loss: 1.018
#   Train accuracy: 0.646
#   Val accuracy: 0.542
# Epoch 40/50
#   Loss: 0.988
#   Train accuracy: 0.639
#   Val accuracy: 0.544
# Epoch 41/50
#   Loss: 0.711
#   Train accuracy: 0.669
#   Val accuracy: 0.545
# Epoch 42/50
#   Loss: 0.519
#   Train accuracy: 0.664
#   Val accuracy: 0.553
# Epoch 43/50
#   Loss: 0.938
#   Train accuracy: 0.658
#   Val accuracy: 0.545
# Epoch 44/50
#   Loss: 1.127
#   Train accuracy: 0.650
#   Val accuracy: 0.543
# Epoch 45/50
#   Loss: 1.100
#   Train accuracy: 0.647
#   Val accuracy: 0.551
# Epoch 46/50
#   Loss: 0.911
#   Train accuracy: 0.662
#   Val accuracy: 0.554
# Epoch 47/50
#   Loss: 0.602
#   Train accuracy: 0.674
#   Val accuracy: 0.554
# Epoch 48/50
#   Loss: 0.887
#   Train accuracy: 0.670
#   Val accuracy: 0.544
# Epoch 49/50
#   Loss: 1.268
#   Train accuracy: 0.682
#   Val accuracy: 0.536
# Epoch 50/50
#   Loss: 1.064
#   Train accuracy: 0.688
#   Val accuracy: 0.544
